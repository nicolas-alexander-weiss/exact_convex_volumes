# %%
var('x,y')
f = x^2 + y^2
dyf = derivative(f,y)
# Out:
# 'x^2 + y^2'

# %%
R = macaulay2('QQ[x,y]')
I = macaulay2.ideal( (str(f), str(dyf)) ); I
# Out:
#         2    2
# ideal (x  + y , 2y)

# %%
macaulay2("eliminate({y}, I)")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/interfaces/expect.py:1518, in ExpectElement.__init__(self, parent, value, is_name, name)
#    1517 try:
# -> 1518     self._name = parent._create(value, name=name)
#    1519 # Convert ValueError and RuntimeError to TypeError for
#    1520 # coercion to work properly.
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/interfaces/interface.py:520, in Interface._create(self, value, name)
#     519 name = self._next_var_name() if name is None else name
# --> 520 self.set(name, value)
#     521 return name
#
# ...
