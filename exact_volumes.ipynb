# %%
# Computation of the intersection of two L(p,n) balls
n = 4
p = 4

# mu0 = (0,0,0,0)
# mu1 = (1,0,0,0)

#########################

from ore_algebra import *

# %%
# Create the ring in n variables
R = PolynomialRing(ZZ, n, 'x'); R
# Out:
# Multivariate Polynomial Ring in x0, x1, x2, x3 over Integer Ring

# %%
# Create the fraction_field in n variables
fracR = R.fraction_field(); fracR
# Out:
# Fraction Field of Multivariate Polynomial Ring in x0, x1, x2, x3 over Integer Ring

# %%
# Create the WeylAlgebra over that fraction_field
WR = OreAlgebra(fracR, 'Dx0,Dx1,Dx2,Dx3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Create the WeylAlgebra over that fraction_field
# ----> 2 WR = OreAlgebra(fracR, 'Dx0,Dx1,Dx2,Dx3')
#
# File ~/Library/SageMath-10-6/lib/python3.12/site-packages/ore_algebra/ore_algebra.py:913, in OreAlgebra(base_ring, check_base_ring, *generators, **kwargs)
#     911 elif len(gens[i]) != 3:
#     912     raise TypeError("unexpected generator declaration")
# --> 913 s = Sigma_class(R, gens[i][1])  # assuming gens[i][1] is either a dict or a callable
#     914 d = Delta_class(R, gens[i][2], s)  # assuming gens[i][2] is either a dict or a callable
#     915 if s(one) != one:
#
# File ~/Library/SageMath-10-6/lib/python3.12/site-packages/ore_algebra/ore_algebra.py:219, in Sigma_class.__init__(self, R, d)
#     217 if not isinstance(d, dict):
#     218     for x in Rgens:
# --> 219         dx = R(d(x))
#     220         my_dict[str(x)] = dx
#     221         if dx != x:
#
# TypeError: 'str' object is not callable
